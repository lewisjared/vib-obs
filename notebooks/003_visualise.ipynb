# %% [markdown]
# # Visualise

# %%
import pandas as pd
pd.options.display.max_rows = None

# %%
INPUT_FILE = "../data/results_20201229T160058.csv"

# %%
df = pd.read_csv(INPUT_FILE, header=[0,1], index_col=[0])
df
# Out:
# name                                wmo-id bom-id                   tz  \
# units                                  nan    nan                  nan
# station
# AIREYS INLET                         95936  86338  Australia/Melbourne
# ARARAT PRISON                        95936  86338  Australia/Melbourne
# AVALON AIRPORT                       95936  86338  Australia/Melbourne
# BAIRNSDALE AIRPORT                   95936  86338  Australia/Melbourne
# BALLARAT AERODROME                   95936  86338  Australia/Melbourne
# BEN NEVIS                            95936  86338  Australia/Melbourne
# BENALLA AIRPORT                      95936  86338  Australia/Melbourne
# BENDIGO AIRPORT                      95936  86338  Australia/Melbourne
# CAPE NELSON LIGHTHOUSE               95936  86338  Australia/Melbourne
# CAPE OTWAY LIGHTHOUSE                95936  86338  Australia/Melbourne
# CASHMORE AIRPORT                     95936  86338  Australia/Melbourne
# ...

# %%
# What locations do we have
df.index.values
# Out:
# array(['AIREYS INLET', 'ARARAT PRISON', 'AVALON AIRPORT',
#        'BAIRNSDALE AIRPORT', 'BALLARAT AERODROME', 'BEN NEVIS',
#        'BENALLA AIRPORT', 'BENDIGO AIRPORT', 'CAPE NELSON LIGHTHOUSE',
#        'CAPE OTWAY LIGHTHOUSE', 'CASHMORE AIRPORT', 'CASTERTON',
#        'CASTLEMAINE PRISON', 'CERBERUS', 'CHARLTON', 'COLDSTREAM',
#        'COMBIENBAR AWS', 'DARTMOOR', 'DARTMOUTH RESERVOIR',
#        'EAST SALE AIRPORT', 'ECHUCA AERODROME', 'EDENHOPE AIRPORT',
#        'EILDON FIRE TOWER', 'ESSENDON AIRPORT', 'FALLS CREEK',
#        'FAWKNER BEACON', 'FERNY CREEK', 'FRANKSTON (BALLAM PARK)',
#        'FRANKSTON BEACH', 'GABO ISLAND LIGHTHOUSE', 'GEELONG RACECOURSE',
#        'GELANTIPY', 'HAMILTON AIRPORT', 'HOGAN ISLAND',
#        'HOPETOUN AIRPORT', 'HORSHAM AERODROME', 'HUNTERS HILL',
#        'KANAGULK', 'KERANG', 'KILMORE GAP', 'KINGFISH B (PLATFORM)',
#        'KYABRAM', 'LAKE EILDON', 'LAKES ENTRANCE (EASTERN BEACH ROAD)',
# ...

# %%
# Look at the results from a given location
df.loc["FAWKNER BEACON"]
# Out:
# name                     units
# wmo-id                   nan                           95936
# bom-id                   nan                           86338
# tz                       nan             Australia/Melbourne
# stn-name                 nan        MELBOURNE (OLYMPIC PARK)
# stn-height               nan                          7.5300
# type                     nan                             AWS
# lat                      nan                        -37.8255
# lon                      nan                        144.9816
# forecast-district-id     nan                       VIC_PW007
# description              nan        Melbourne (Olympic Park)
# apparent_temp            Celsius                         NaN
# delta_t                  Celsius                         NaN
# gust_kmh                 km/h                        22.0000
# wind_gust_spd            knots                       12.0000
# air_temperature          Celsius                         NaN
# ...

# %%
# And extract a single value
df.loc["FAWKNER BEACON", "wind_spd"].squeeze()
# Out:
# 10.0

# %%
# Look at all wind speeds
df.loc[:, "wind_spd"]
# Out:
# units                                knots
# station
# AIREYS INLET                           6.0
# ARARAT PRISON                          0.0
# AVALON AIRPORT                        10.0
# BAIRNSDALE AIRPORT                     7.0
# BALLARAT AERODROME                    10.0
# BEN NEVIS                             12.0
# BENALLA AIRPORT                        1.0
# BENDIGO AIRPORT                       15.0
# CAPE NELSON LIGHTHOUSE                12.0
# CAPE OTWAY LIGHTHOUSE                 10.0
# CASHMORE AIRPORT                      14.0
# CASTERTON                             10.0
# CASTLEMAINE PRISON                     1.0
# CERBERUS                               6.0
# CHARLTON                               7.0
# COLDSTREAM                            10.0
# COMBIENBAR AWS                         0.0
# DARTMOOR                               8.0
# DARTMOUTH RESERVOIR                   18.0
# EAST SALE AIRPORT                      3.0
# ECHUCA AERODROME                      16.0
# ...
